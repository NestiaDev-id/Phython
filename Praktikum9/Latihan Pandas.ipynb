# %% [markdown]
# # Import library

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Code

# %%
df = pd.read_csv("C:/Users/basisdata/Downloads/Data BPJS 2019.csv", index_col=[0])
df.head()
# Out:
#    Nomor peserta  Nomor keluarga       Bobot ID Kunjungan FKTP  \
# 0    157978748.0        50765420   20.064983         958073632
# 1     95085112.0        26931775    2.626307  449590620P000054
# 2    224470578.0       227368233    1.051830  467490619P000001
# 3     63871289.0        62313678  364.741455  254321219Y002368
# 4     29915626.0       113446188    1.050523   88681119P000020
#
#   Tanggal datang kunjungan FKTP Tanggal pulang kunjungan FKTP  Provinsi FKTP  \
# 0                    2019-08-01                    2019-08-01             61
# 1                    2020-06-17                    2020-06-17             51
# 2                    2019-06-01                    2019-06-01             35
# 3                    2019-12-21                    2019-12-21             34
# 4                    2019-11-04                    2019-11-04             35
#
#    Kabupaten/Kota FKTP  Kepemilikan FKTP  Jenis FKTP  ...  \
# 0                 6108                 3           1  ...
# ...

# %%
print("Data diatas memiliki {} baris dan {} kolom".format(df.shape[0],df.shape[1]))
# Out:
# Data diatas memiliki 500000 baris dan 26 kolom

# %%
# Mengubah tipe kolom tanggal datang dan pulang ke pd datetime
df["Tanggal datang kunjungan FKTP"] = pd.to_datetime(df["Tanggal datang kunjungan FKTP"])
df["Tanggal pulang kunjungan FKTP"] = pd.to_datetime(df["Tanggal pulang kunjungan FKTP"])

df["Tahun datang"] = df["Tanggal datang kunjungan FKTP"].dt.year
df["Bulan datang"] = df["Tanggal datang kunjungan FKTP"].dt.month
df["Tanggal datang"] = df["Tanggal datang kunjungan FKTP"].dt.day

df["Tahun pulang"] = df["Tanggal pulang kunjungan FKTP"].dt.year
df["Bulan pulang"] = df["Tanggal pulang kunjungan FKTP"].dt.month
df["Tanggal pulang"] = df["Tanggal pulang kunjungan FKTP"].dt.day

df
# Out:
#         Nomor peserta  Nomor keluarga       Bobot ID Kunjungan FKTP  \
# 0         157978748.0        50765420   20.064983         958073632
# 1          95085112.0        26931775    2.626307  449590620P000054
# 2         224470578.0       227368233    1.051830  467490619P000001
# 3          63871289.0        62313678  364.741455  254321219Y002368
# 4          29915626.0       113446188    1.050523   88681119P000020
# ...               ...             ...         ...               ...
# 499995     52248195.0        99457992  442.270020   58190419Y006723
# 499996    100074300.0       151146239   59.774738  276060720P000131
# 499997     95115654.0        95115654  155.687454  210781019P000426
# 499998    100522053.0       100522053   51.685715  167730919P000325
# 499999     94310305.0       127908459   83.201393  401411119P000296
#
#        Tanggal datang kunjungan FKTP Tanggal pulang kunjungan FKTP  \
# 0                         2019-08-01                    2019-08-01
# ...

# %%
# Mengganti kolom kelas str menjadi numeric
df['Status'] = df ["Kelas Status Pulang Peserta"].map({"Sehat" : 1, "Belum_Sehat":0})
df
# Out:
#         Nomor peserta  Nomor keluarga       Bobot ID Kunjungan FKTP  \
# 0         157978748.0        50765420   20.064983         958073632
# 1          95085112.0        26931775    2.626307  449590620P000054
# 2         224470578.0       227368233    1.051830  467490619P000001
# 3          63871289.0        62313678  364.741455  254321219Y002368
# 4          29915626.0       113446188    1.050523   88681119P000020
# ...               ...             ...         ...               ...
# 499995     52248195.0        99457992  442.270020   58190419Y006723
# 499996    100074300.0       151146239   59.774738  276060720P000131
# 499997     95115654.0        95115654  155.687454  210781019P000426
# 499998    100522053.0       100522053   51.685715  167730919P000325
# 499999     94310305.0       127908459   83.201393  401411119P000296
#
#        Tanggal datang kunjungan FKTP Tanggal pulang kunjungan FKTP  \
# 0                         2019-08-01                    2019-08-01
# ...

# %%
tahun = [2019,2019,2020,2021]

# %%
# Fungsi missing check
def missing_check(df) :
    missing = df.isnull().sum()
    per_miss = missing/len(df)
    data_type = df.dtypes
    number_unique = df.nunique()
    return pd.DataFrame({"Missing":missing,
                        "Percent_Missing":per_miss,
                       "Data_Types": data_type,
                        "Number_of_unique":number_unique}).style.format({'Percent_Missing' : "{:.2%}"})

# %%
missing_check(df)
# Out:
# <style  type="text/css" >
# </style><table id="T_b35d4398_eaf5_11ed_b769_c81f66456587" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Missing</th>        <th class="col_heading level0 col1" >Percent_Missing</th>        <th class="col_heading level0 col2" >Data_Types</th>        <th class="col_heading level0 col3" >Number_of_unique</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b35d4398_eaf5_11ed_b769_c81f66456587level0_row0" class="row_heading level0 row0" >Nomor peserta</th>
#                         <td id="T_b35d4398_eaf5_11ed_b769_c81f66456587row0_col0" class="data row0 col0" >0</td>
#                         <td id="T_b35d4398_eaf5_11ed_b769_c81f66456587row0_col1" class="data row0 col1" >0.00%</td>
#                         <td id="T_b35d4398_eaf5_11ed_b769_c81f66456587row0_col2" class="data row0 col2" >float64</td>
# ...
